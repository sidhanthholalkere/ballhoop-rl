# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.animation as animation
from gym_ballhoop.envs import params, rendering, transition, update

# %%
baseline = pd.read_csv('../baseline.csv')

# %%
state = np.asarray([0, 0, 0, 0, params.Ro - params.Rb, 0, 0, 0, 1])
state
# Out:
# array([0.        , 0.        , 0.        , 0.        , 0.09023421,
#        0.        , 0.        , 0.        , 1.        ])

# %%
times = []
states = []

# %%
for i in range(int(3000)):
    times.append(i * params.h)
    states.append(state)
    t_i = 0.2
    if i >= 1000 and i <= 2000:
        t_i = -0.2
    state = update.update_all(state, t_i, debug=False)

# %%
plt.plot(times, [state[0] for state in states])
plt.plot(baseline['time'], baseline['th'])
plt.show()

# %%
plt.plot(times, [state[1] for state in states])
plt.plot(baseline['time'], baseline['Dth'])
plt.show()

# %%
plt.plot(times, [state[2] for state in states])
plt.plot(baseline['time'], baseline['psi'])
plt.show()

# %%
plt.plot(times, [state[3] for state in states])
plt.plot(baseline['time'], baseline['Dpsi'])
plt.show()

# %%
plt.plot(times, [state[4] for state in states])
plt.plot(baseline['time'], baseline['r'])
plt.show()

# %%
plt.plot(times, [state[5] for state in states])
plt.plot(baseline['time'], baseline['Dr'])
plt.show()

# %%
plt.plot(times, [state[6] for state in states])
plt.plot(baseline['time'], baseline['phi'])
plt.show()

# %%
plt.plot(times, [state[7] for state in states])
plt.plot(baseline['time'], baseline['Dphi'])
plt.show()

# %%
plt.plot(times, [state[8] for state in states])
plt.plot(baseline['time'], baseline['mode'])
plt.show()
